# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

cx=0.3333
cy=0.3333
cz=0.3334
def f(x, y):
    z=1-(x+y)
    #print("{:.2f}".format(z))
    return  1-(np.minimum(x,cx)+np.minimum(y,cy)+np.minimum(z,cz)) #np.sin(np.sqrt(x ** 2 + y ** 2)) not min!
	
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
'''
# Normalize to [0,1]
norm = plt.Normalize(Z.min(), Z.max())
colors = cm.viridis(norm(Z))
rcount, ccount, _ = colors.shape

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe')
plt.show()
'''

# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating color map
my_cmap = plt.get_cmap('hot')
 
# Creating plot
surf = ax.plot_surface(X, Y, Z,
                       cmap = my_cmap,
                       edgecolor ='none')
 
fig.colorbar(surf, ax = ax,
             shrink = 0.5, aspect = 5)
 
ax.set_title('Surface plot')
 
# show plot
ax.axis('equal')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

cx=0.5
cy=0.5
cz=0.0
def f(x, y):
    z=1-(x+y)
    #print("{:.2f}".format(z))
    return  1-(np.minimum(x,cx)+np.minimum(y,cy)+np.minimum(z,cz)) #np.sin(np.sqrt(x ** 2 + y ** 2)) not min!
	
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)


# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating color map
my_cmap = plt.get_cmap('hot')
 
# Creating plot
surf = ax.plot_surface(X, Y, Z,
                       cmap = my_cmap,
                       edgecolor ='none')
 
fig.colorbar(surf, ax = ax,
             shrink = 0.5, aspect = 5)
 
ax.set_title('Distance from 0.5,0.5,0')
 
# show plot
ax.axis('equal')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

cx=0.8
cy=0.1
cz=0.1
def f(x, y):
    z=1-(x+y)
    #print("{:.2f}".format(z))
    return  1-(np.minimum(x,cx)+np.minimum(y,cy)+np.minimum(z,cz)) #np.sin(np.sqrt(x ** 2 + y ** 2)) not min!
	
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)
'''
# Normalize to [0,1]
norm = plt.Normalize(Z.min(), Z.max())
colors = cm.viridis(norm(Z))
rcount, ccount, _ = colors.shape

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe')
plt.show()
'''

# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating color map
my_cmap = plt.get_cmap('hot')
 
# Creating plot
surf = ax.plot_surface(X, Y, Z,
                       cmap = my_cmap,
                       edgecolor ='none')
 
fig.colorbar(surf, ax = ax,
             shrink = 0.5, aspect = 5)
 
ax.set_title('Surface plot')
 
# show plot
ax.axis('equal')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

cx=0.0
cy=0.1
cz=0.9
def f(x, y):
    z=1-(x+y)
    #print("{:.2f}".format(z))
    return  1-(np.minimum(x,cx)+np.minimum(y,cy)+np.minimum(z,cz)) #np.sin(np.sqrt(x ** 2 + y ** 2)) not min!
	
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)


# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating color map
my_cmap = plt.get_cmap('hot')
 
# Creating plot
surf = ax.plot_surface(X, Y, Z,
                       cmap = my_cmap,
                       edgecolor ='none')
 
fig.colorbar(surf, ax = ax,
             shrink = 0.5, aspect = 5)
 
ax.set_title('Surface plot')
 
# show plot
ax.axis('equal')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm


def f(x, y, cx,cy,cz):
    z=1-(x+y)
    #print("{:.2f}".format(z))
    return  1-(np.minimum(x,cx)+np.minimum(y,cy)+np.minimum(z,cz)) #np.sin(np.sqrt(x ** 2 + y ** 2)) not min!
    #return np.sqrt( np.power(x-cx,2)+np.power(y-cy,2)+np.power(z-cz,2))
	
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

X, Y = np.meshgrid(x, y)

Z1 = f(X, Y, 0.33, 0.33, 0.34)
Z2 = f(X, Y, 0.05, 0.05, 0.90)
Z3 = f(X, Y, 0.20, 0.60, 0.40)
Z4 = f(X, Y, 0.90, 0.05, 0.05)


# Creating figure
fig = plt.figure(figsize =(10, 10))
#ax = plt.axes(projection ='3d')

    
# Creating color map
my_cmap = plt.get_cmap('hot')
 
ax = fig.add_subplot(2, 2, 1, projection='3d')
ax.plot_surface(X, Y, Z1, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.33, 0.33, 0.34)', fontsize=20, y=0.0,pad=-25)
# set up the axes for the second plot------------------------------
ax = fig.add_subplot(2, 2, 2, projection='3d')
surf = ax.plot_surface(X, Y, Z2, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.05, 0.05, 0.90)', fontsize=20, y=0.0,pad=-25)
# -----------------------------------------------------------------
ax = fig.add_subplot(2, 2, 3, projection='3d')
surf = ax.plot_surface(X, Y, Z3, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.20, 0.60, 0.40)', fontsize=20, y=0.0,pad=-25)
# -----------------------------------------------------------------
ax = fig.add_subplot(2, 2, 4, projection='3d')
surf = ax.plot_surface(X, Y, Z4, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.90, 0.05, 0.05)', fontsize=20, y=0.0,pad=-25)


#fig.colorbar(surf, ax = ax,             shrink = 0.5, aspect = 10)
 
plt.suptitle('Distance in MinFunction Metric',horizontalalignment="center")
#plt.savefig('H:\\geometryDistance02.png', bbox_inches='tight', dpi=300)
# show plot
ax.axis('equal')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm


def f(x, y, cx,cy,cz):        
    return  1-(np.minimum(x,cx)+np.minimum(y,cy))
    #return np.sqrt( np.power(x-cx,2)+np.power(y-cy,2)+np.power(z-cz,2))
	
x = np.linspace(0, 1, 50)
y = np.linspace(0, 1, 50)

X, Y = np.meshgrid(x, y)

Z1 = f(X, Y, 0.33, 0.33, 0.34)
Z2 = f(X, Y, 0.05, 0.05, 0.90)
Z3 = f(X, Y, 0.20, 0.60, 0.40)
Z4 = f(X, Y, 0.90, 0.05, 0.05)


# Creating figure
fig = plt.figure(figsize =(10, 10))
#ax = plt.axes(projection ='3d')

    
# Creating color map
my_cmap = plt.get_cmap('hot')
 
ax = fig.add_subplot(2, 2, 1, projection='3d')
ax.plot_surface(X, Y, Z1, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.33, 0.33, 0.34)', fontsize=20, y=0.0,pad=-25)
# set up the axes for the second plot------------------------------
ax = fig.add_subplot(2, 2, 2, projection='3d')
surf = ax.plot_surface(X, Y, Z2, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.05, 0.05, 0.90)', fontsize=20, y=0.0,pad=-25)
# -----------------------------------------------------------------
ax = fig.add_subplot(2, 2, 3, projection='3d')
surf = ax.plot_surface(X, Y, Z3, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.20, 0.60, 0.40)', fontsize=20, y=0.0,pad=-25)
# -----------------------------------------------------------------
ax = fig.add_subplot(2, 2, 4, projection='3d')
surf = ax.plot_surface(X, Y, Z4, cmap = my_cmap, edgecolor ='none')
ax.set_title('(0.90, 0.05, 0.05)', fontsize=20, y=0.0,pad=-25)


#fig.colorbar(surf, ax = ax,             shrink = 0.5, aspect = 10)
fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.98, 0.40, 0.03, 0.15]) #l, b, w, h
fig.colorbar(surf, cax=cbar_ax, shrink = 0.1, aspect = 55)
 
plt.suptitle('Distance in MinFunction Metric',horizontalalignment="center", fontsize=30)
#plt.savefig('H:\\geometryDistance03.png', bbox_inches='tight', dpi=300)
# show plot
ax.axis('equal')
plt.show()

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import math

cx=0.5
cy=0.5
cz=0.0
def dis1(x, y):
    z=1-(x+y)    
    return np.sqrt( np.power(x-cx,2)+np.power(y-cy,2)+np.power(z-cz,2))#math.sqrt(np.power(x-cx,2))# + (y-cy)** 2 + (z-cz)** 2)     

def dis2(x, y):       
    return np.sqrt( np.power(x-cx,2)+np.power(y-cy,2))
	
x = np.linspace(0, 1, 30)
y = np.linspace(0, 1, 30)

X, Y = np.meshgrid(x, y)
Z1 = dis1(X, Y)
Z2 = dis2(X, Y)


fig = plt.figure(figsize =(10, 12))
#ax = plt.axes(projection ='3d')
 

my_cmap = plt.get_cmap('hot')
 
    
ax = fig.add_subplot(2, 2, 1, projection='3d')
ax.plot_surface(X, Y, Z1, cmap = my_cmap, edgecolor ='none')
ax.set_title('dis1', fontsize=20, y=0.0,pad=-25)
#------------------------------------------------------------------
ax = fig.add_subplot(2, 2, 2, projection='3d')
ax.plot_surface(X, Y, Z2, cmap = my_cmap, edgecolor ='none')
ax.set_title('dis2', fontsize=20, y=0.0,pad=-25)
#------------------------------------------------------------------
ax = fig.add_subplot(2, 2, 3, projection='3d')
ax.plot_surface(X, Y, Z2, cmap = my_cmap, edgecolor ='none')
ax.set_title('dis3', fontsize=20, y=0.0,pad=-25)
#------------------------------------------------------------------
ax = fig.add_subplot(2, 2, 4, projection='3d')
ax.plot_surface(X, Y, Z2, cmap = my_cmap, edgecolor ='none')
ax.set_title('dis4', fontsize=20, y=0.0,pad=-25)
#------------------------------------------------------------------
 
#fig.colorbar(surf, ax = ax,             shrink = 0.4, aspect = 15)

fig.subplots_adjust(right=0.9)
cbar_ax = fig.add_axes([0.98, 0.40, 0.03, 0.15]) #l, b, w, h
fig.colorbar(surf, cax=cbar_ax, shrink = 0.1, aspect = 55)
 

plt.suptitle('Distance in Ecludian Metric',horizontalalignment="center", fontsize=30)
# show plot
ax.axis('equal')
plt.show()
